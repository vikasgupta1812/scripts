# %%
library(jsonlite)
library(dplyr)
# Out:
# Attaching package: 'dplyr'
#
# The following objects are masked from 'package:stats':
#
#     filter, lag
#
# The following objects are masked from 'package:base':
#
#     intersect, setdiff, setequal, union

# %%
jsondata <- jsonlite::fromJSON("https://api.github.com/users/vikasgupta1812/repos")

# %%
class(jsondata); dim(jsondata)

# %%
jsondata %>% 
    head
# Out:
#         id                                 name
# 1 47212664                     CERN_Time_Series
# 2 26408254            Coursera-capstone-project
# 3 25780339 Coursera-Predictive-Machine-Learning
# 4 25788424                  Coursera-Regression
# 5 19458481                              courses
# 6 19013673                         Data-Science
#                                             full_name    owner.login owner.id
# 1                     vikasgupta1812/CERN_Time_Series vikasgupta1812  4309626
# 2            vikasgupta1812/Coursera-capstone-project vikasgupta1812  4309626
# 3 vikasgupta1812/Coursera-Predictive-Machine-Learning vikasgupta1812  4309626
# 4                  vikasgupta1812/Coursera-Regression vikasgupta1812  4309626
# 5                              vikasgupta1812/courses vikasgupta1812  4309626
# 6                         vikasgupta1812/Data-Science vikasgupta1812  4309626
#                                      owner.avatar_url owner.gravatar_id
# ...

# %%
names(jsondata)
# Out:
#  [1] "id"                "name"              "full_name"
#  [4] "owner"             "private"           "html_url"
#  [7] "description"       "fork"              "url"
# [10] "forks_url"         "keys_url"          "collaborators_url"
# [13] "teams_url"         "hooks_url"         "issue_events_url"
# [16] "events_url"        "assignees_url"     "branches_url"
# [19] "tags_url"          "blobs_url"         "git_tags_url"
# [22] "git_refs_url"      "trees_url"         "statuses_url"
# [25] "languages_url"     "stargazers_url"    "contributors_url"
# [28] "subscribers_url"   "subscription_url"  "commits_url"
# [31] "git_commits_url"   "comments_url"      "issue_comment_url"
# [34] "contents_url"      "compare_url"       "merges_url"
# [37] "archive_url"       "downloads_url"     "issues_url"
# [40] "pulls_url"         "milestones_url"    "notifications_url"
# [43] "labels_url"        "releases_url"      "deployments_url"
# [46] "created_at"        "updated_at"        "pushed_at"
# ...

# %%
names(jsondata) %>% 
    cat(sep='\n')
# Out:
# id
# name
# full_name
# owner
# private
# html_url
# description
# fork
# url
# forks_url
# keys_url
# collaborators_url
# teams_url
# hooks_url
# issue_events_url
# events_url
# assignees_url
# branches_url
# tags_url
# blobs_url
# git_tags_url
# git_refs_url
# trees_url
# statuses_url
# languages_url
# stargazers_url
# contributors_url
# subscribers_url
# subscription_url
# commits_url
# git_commits_url
# comments_url
# issue_comment_url
# contents_url
# compare_url
# merges_url
# archive_url
# downloads_url
# issues_url
# pulls_url
# milestones_url
# notifications_url
# labels_url
# releases_url
# deployments_url
# created_at
# updated_at
# pushed_at
# git_url
# ssh_url
# clone_url
# svn_url
# homepage
# size
# stargazers_count
# watchers_count
# language
# has_issues
# has_downloads
# has_wiki
# has_pages
# forks_count
# mirror_url
# open_issues_count
# forks
# open_issues
# watchers
# default_branch

# %%
jsondata$owner$login
# Out:
#  [1] "vikasgupta1812" "vikasgupta1812" "vikasgupta1812" "vikasgupta1812"
#  [5] "vikasgupta1812" "vikasgupta1812" "vikasgupta1812" "vikasgupta1812"
#  [9] "vikasgupta1812" "vikasgupta1812" "vikasgupta1812" "vikasgupta1812"
# [13] "vikasgupta1812" "vikasgupta1812" "vikasgupta1812" "vikasgupta1812"
# [17] "vikasgupta1812" "vikasgupta1812" "vikasgupta1812" "vikasgupta1812"
# [21] "vikasgupta1812" "vikasgupta1812" "vikasgupta1812" "vikasgupta1812"
# [25] "vikasgupta1812" "vikasgupta1812" "vikasgupta1812" "vikasgupta1812"
# [29] "vikasgupta1812" "vikasgupta1812"

# %% [markdown]
# #### Convert dataframe to json

# %%
head(iris)
# Out:
#   Sepal.Length Sepal.Width Petal.Length Petal.Width Species
# 1          5.1         3.5          1.4         0.2  setosa
# 2          4.9         3.0          1.4         0.2  setosa
# 3          4.7         3.2          1.3         0.2  setosa
# 4          4.6         3.1          1.5         0.2  setosa
# 5          5.0         3.6          1.4         0.2  setosa
# 6          5.4         3.9          1.7         0.4  setosa

# %%
myjson = toJSON(head(iris), pretty = TRUE)

# %%
class(myjson)
# Out:
# [1] "json"

# %%
cat(myjson)
# Out:
# [
#   {
#     "Sepal.Length": 5.1,
#     "Sepal.Width": 3.5,
#     "Petal.Length": 1.4,
#     "Petal.Width": 0.2,
#     "Species": "setosa"
#   },
#   {
#     "Sepal.Length": 4.9,
#     "Sepal.Width": 3,
#     "Petal.Length": 1.4,
#     "Petal.Width": 0.2,
#     "Species": "setosa"
#   },
#   {
#     "Sepal.Length": 4.7,
#     "Sepal.Width": 3.2,
#     "Petal.Length": 1.3,
#     "Petal.Width": 0.2,
#     "Species": "setosa"
#   },
#   {
#     "Sepal.Length": 4.6,
#     "Sepal.Width": 3.1,
#     "Petal.Length": 1.5,
#     "Petal.Width": 0.2,
#     "Species": "setosa"
#   },
#   {
#     "Sepal.Length": 5,
#     "Sepal.Width": 3.6,
#     "Petal.Length": 1.4,
#     "Petal.Width": 0.2,
#     "Species": "setosa"
#   },
#   {
#     "Sepal.Length": 5.4,
#     "Sepal.Width": 3.9,
#     "Petal.Length": 1.7,
#     "Petal.Width": 0.4,
#     "Species": "setosa"
#   }
# ]

# %%
iris2 <- fromJSON(myjson); iris2
# Out:
#   Sepal.Length Sepal.Width Petal.Length Petal.Width Species
# 1          5.1         3.5          1.4         0.2  setosa
# 2          4.9         3.0          1.4         0.2  setosa
# 3          4.7         3.2          1.3         0.2  setosa
# 4          4.6         3.1          1.5         0.2  setosa
# 5          5.0         3.6          1.4         0.2  setosa
# 6          5.4         3.9          1.7         0.4  setosa
